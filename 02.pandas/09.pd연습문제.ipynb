# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
# 1) a
iris.groupby('species').agg(['mean','std','min','max','count']).round(2)
# Out:
#            sepal_length                       sepal_width                  \
#                    mean   std  min  max count        mean   std  min  max
# species
# setosa             5.01  0.35  4.3  5.8    50        3.43  0.38  2.3  4.4
# versicolor         5.94  0.52  4.9  7.0    50        2.77  0.31  2.0  3.4
# virginica          6.59  0.64  4.9  7.9    50        2.97  0.32  2.2  3.8
#
#                  petal_length                       petal_width             \
#            count         mean   std  min  max count        mean   std  min
# species
# setosa        50         1.46  0.17  1.0  1.9    50        0.25  0.11  0.1
# versicolor    50         4.26  0.47  3.0  5.1    50        1.33  0.20  1.0
# virginica     50         5.55  0.55  4.5  6.9    50        2.03  0.27  1.4
#
#
#             max count
# species
# setosa      0.6    50
# versicolor  1.8    50
# virginica   2.5    50

# %%
lower = Q1-1.5*(Q3-Q1)
lower                       #이거보다 작은 데이터는 이상치
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f3fd5e83d685> in <module>
# ----> 1 lower = Q1-1.5*(Q3-Q1)
#       2 lower                       #이거보다 작은 데이터는 이상치
#
# NameError: name 'Q1' is not defined

# %%
upper = Q3 + 1.5*(Q3-Q1)
upper                        #이거보다 큰 데이터는 이상치
# Out:
# sepal_length     8.35
# sepal_width      4.05
# petal_length    10.35
# petal_width      4.05
# dtype: float64

# %%
s = iris[iris.species == 'setosa']['sepal_length']
s

# %%
Q1 = s.quantile(0.25)
Q3 = s.quantile(0.75)
lower = Q1-1.5*(Q3-Q1)
upper = Q3+1.5*(Q3-Q1)
lower, upper
# Out:
# (4.199999999999999, 5.800000000000001)

# %%
s[(s<lower)|(s>upper)] = np.nan

# %%
s.mean() , s.std()
# Out:
# (5.005999999999999, 0.3524896872134512)

# %%
def iris_mestd(x,y):
    d = iris[iris.species==x][y]
    Q1 = d.quantile(0.25)
    Q3 = d.quantile(0.75)
    lower = Q1 - 1.5*(Q3-Q1)
    upper = Q3 + 1.5*(Q3-Q1)
    d[(d<lower)|(d>upper)] = np.nan
    return d.mean(),d.std()

# %%
iris_mestd('setosa','sepal_length')
# Out:
# (5.005999999999999, 0.3524896872134512)

# %%
iris_mestd('setosa','sepal_width')
# Out:
# (3.4312500000000004, 0.32034306743094015)

# %%
iris_mestd('setosa','petal_length')
# Out:
# (1.4608695652173913, 0.12906201931985212)

# %%
iris_mestd('setosa','petal_width')
# Out:
# (0.23333333333333328, 0.08588298157855664)

# %%
iris_mestd('versicolor','sepal_length')
# Out:
# (5.936, 0.5161711470638635)

# %%
iris_mestd('versicolor','sepal_width')
# Out:
# (2.7700000000000005, 0.3137983233784114)

# %%
iris_mestd('versicolor','petal_length')
# Out:
# (4.285714285714285, 0.4377975178854565)

# %%
iris_mestd('versicolor','petal_width')
# Out:
# (1.3259999999999998, 0.197752680004544)

# %%
iris_mestd('virginica','sepal_length')
# Out:
# (6.6224489795918355, 0.593459246748267)

# %%
iris_mestd('virginica','sepal_width')
# Out:
# (2.95531914893617, 0.26027452951125174)

# %%
iris_mestd('virginica','petal_length')
# Out:
# (5.552, 0.5518946956639835)

# %%
iris_mestd('virginica','petal_width')
# Out:
# (2.026, 0.27465005563666733)

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
#2번문제
Titanic = sns.load_dataset('titanic')
Titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic['adult/child'] = titanic.age.apply(lambda x: 'adult' if x > 20 else 'child')

# %%
# 2) a
Titanic['category1'] = Titanic.age.apply(lambda x: Titanic['sex'] if x > 20 else 'child')
Titanic.head(20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-9eb237edbbd7> in <module>
#       1 # 2) a
# ----> 2 Titanic['category1'] = Titanic.age.apply(lambda x: Titanic['sex'] if x > 20 else 'child')
#       3 Titanic.head(20)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4141             # GH 25959 use pd.array instead of tolist
#    4142             # so extension arrays can be used
# -> 4143             return self._constructor_expanddim(pd_array(mapped), index=self.index)
#    4144         else:
#    4145             return self._constructor(mapped, index=self.index).__finalize__(
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     568                     if is_named_tuple(data[0]) and columns is None:
#     569                         columns = data[0]._fields
# --> 570                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     571                     columns = ensure_index(columns)
#     572
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     532         )
#     533     elif isinstance(data[0], ABCSeries):
# --> 534         return _list_of_series_to_arrays(
#     535             data, columns, coerce_float=coerce_float, dtype=dtype
#     536         )
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_of_series_to_arrays(data, columns, coerce_float, dtype)
#     595             indexer = indexer_cache[id(index)]
#     596         else:
# --> 597             indexer = indexer_cache[id(index)] = index.get_indexer(columns)
#     598
#     599         values = extract_array(s, extract_numpy=True)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'get_indexer'

# %%
# 2)b 
Titanic.age.mean()
# Out:
# 29.69911764705882

# %%
Titanic.age.fillna(Titanic.age.mean(),inplace=True)
Titanic.round(2)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.25        S   Third
# 1           1       1  female  38.0      1      0  71.28        C   First
# 2           1       3  female  26.0      0      0   7.92        S   Third
# 3           1       1  female  35.0      1      0  53.10        S   First
# 4           0       3    male  35.0      0      0   8.05        S   Third
# ..        ...     ...     ...   ...    ...    ...    ...      ...     ...
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female  29.7      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone category1
# 0      man        True  NaN  Southampton    no  False         k
# 1    woman       False    C    Cherbourg   yes  False         k
# 2    woman       False  NaN  Southampton   yes   True         k
# 3    woman       False    C  Southampton   yes  False         k
# 4      man        True  NaN  Southampton    no   True         k
# ..     ...         ...  ...          ...   ...    ...       ...
# 886    man        True  NaN  Southampton    no   True         k
# 887  woman       False    B  Southampton   yes   True     child
# 888  woman       False  NaN  Southampton    no  False     child
# 889    man        True    C    Cherbourg   yes   True         k
# 890    man        True  NaN   Queenstown    no   True         k
#
# [891 rows x 16 columns]

# %%
# 2 ) 
Titanic.groupby('sex')[['survived']].mean().round(2)
# Out:
#         survived
# sex
# female      0.74
# male        0.19

# %%
Titanic.groupby('class')[['survived']].mean().round(2)
# Out:
#         survived
# class
# First       0.63
# Second      0.47
# Third       0.24

# %%
Titanic.groupby('embark_town')[['survived']].mean().round(2)
# Out:
#              survived
# embark_town
# Cherbourg        0.55
# Queenstown       0.39
# Southampton      0.34

# %%
# 3번문제)
mpg = sns.load_dataset('mpg')
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# a)
mpg['hp_per_cc'] = ( mpg['horsepower']/mpg['displacement'] *100).round(2)
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name  hp_per_cc
# 0            70     usa  chevrolet chevelle malibu      42.35
# 1            70     usa          buick skylark 320      47.14
# 2            70     usa         plymouth satellite      47.17
# 3            70     usa              amc rebel sst      49.34
# 4            70     usa                ford torino      46.36
# ..          ...     ...                        ...        ...
# 393          82     usa            ford mustang gl      61.43
# 394          82  europe                  vw pickup      53.61
# 395          82     usa              dodge rampage      62.22
# 396          82     usa                ford ranger      65.83
# 397          82     usa                 chevy s-10      68.91
#
# [398 rows x 10 columns]

# %%
# b)
k = mpg['name'].str.split()
mpg['manufacturer'] = k.str[0]
mpg.head(3)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
#
#    model_year origin                       name  hp_per_cc manufacturer
# 0          70    usa  chevrolet chevelle malibu      42.35    chevrolet
# 1          70    usa          buick skylark 320      47.14        buick
# 2          70    usa         plymouth satellite      47.17     plymouth

# %%
k = mpg['name'].str.split()
mpg['model'] = k.str[1:]
del mpg['name']
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin  hp_per_cc manufacturer               model
# 0            70     usa      42.35    chevrolet  [chevelle, malibu]
# 1            70     usa      47.14        buick      [skylark, 320]
# 2            70     usa      47.17     plymouth         [satellite]
# 3            70     usa      49.34          amc        [rebel, sst]
# 4            70     usa      46.36         ford            [torino]
# ..          ...     ...        ...          ...                 ...
# 393          82     usa      61.43         ford       [mustang, gl]
# 394          82  europe      53.61           vw            [pickup]
# 395          82     usa      62.22        dodge           [rampage]
# 396          82     usa      65.83         ford            [ranger]
# 397          82     usa      68.91        chevy              [s-10]
#
# [398 rows x 11 columns]

# %%
#c
mpg.groupby('cylinders')[['mpg']].mean().round(2)
# Out:
#              mpg
# cylinders
# 3          20.55
# 4          29.29
# 5          27.37
# 6          19.99
# 8          14.96

# %%
#d
mpg.groupby('origin')[['hp_per_cc']].mean().round(2)
# Out:
#         hp_per_cc
# origin
# europe      74.00
# japan       78.95
# usa         51.21

# %%
# 폐지된 주소는 삭제되도록 필터링
df = df[df['폐지여부'] == '존재']
len(df)

# %%
#e
np.nan = mpg.groupby('manufacturer')['model'].count() >5

# %%
mpg.groupby('manufacturer')['model']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __repr__(self)
#    1299         show_dimensions = get_option("display.show_dimensions")
#    1300
# -> 1301         self.to_string(
#    1302             buf=buf,
#    1303             name=self.name,
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1370             max_rows=max_rows,
#    1371         )
# -> 1372         result = formatter.to_string()
#    1373
#    1374         # catch contract violations
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     367             return f"{type(self.series).__name__}([], {footer})"
#     368
# --> 369         fmt_index, have_header = self._get_formatted_index()
#     370         fmt_values = self._get_formatted_values()
#     371
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatted_index(self)
#     348         else:
#     349             have_header = index.name is not None
# --> 350             fmt_index = index.format(name=True)
#     351         return fmt_index, have_header
#     352
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in format(self, name, formatter, na_rep)
#     976             return header + list(self.map(formatter))
#     977
# --> 978         return self._format_with_header(header, na_rep=na_rep)
#     979
#     980     def _format_with_header(
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _format_with_header(self, header, na_rep)
#     986
#     987         if is_object_dtype(values.dtype):
# --> 988             values = lib.maybe_convert_objects(values, safe=1)
#     989
#     990         if is_object_dtype(values.dtype):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_objects()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     139         if len(self) == 1:
#     140             return converter(self.iloc[0])
# --> 141         raise TypeError(f"cannot convert the series to {converter}")
#     142
#     143     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'float'>

# %%
mpg.groupby('manufacturer')['model'].dropna()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-0fd85d82f593> in <module>
# ----> 1 mpg.groupby('manufacturer')['model'].dropna()
#
# TypeError: 'bool' object is not callable
